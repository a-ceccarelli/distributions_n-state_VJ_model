# %%
#importing useful libraries
import numpy as np
import matplotlib.pyplot as plt

#getting current directory
import os
cwd = os.getcwd()

import matplotlib as mpl
mpl.rc('text', usetex=True)
mpl.rc('text.latex', preamble=r'\usepackage{amsmath}')

#importing all the functions contained in "functions.py"
# %run ../functions

# %%
#time lengths
delta_t = 0.3 
T = 5

#define parameters of the two-state model
V = np.array([2000, -1500])
Lambda = np.array([1, 0.5])
P = np.array([[0.0, 1], [1, 0.0]])
sigma = 50
n = Lambda.shape[0]

#running the model with plot of the track
n_state_model(delta_t, T, V, Lambda, P, sigma,
              plot=True, plot_png_title="tracks_2_rates.png", plot_legend=True,
              plot_ylabel=r'$t \ \ (\boldsymbol{\lambda}\times 1)$')
plt.show()

# %%
#time lengths
delta_t = 0.3 
T = 5

#define parameters of the two-state model with ratesx10
V = np.array([2000, -1500])
Lambda = np.array([1, 0.5])*10
P = np.array([[0.0, 1], [1, 0.0]])
sigma = 50
n = Lambda.shape[0]

#running the model with plot of the track
n_state_model(delta_t, T, V, Lambda, P, sigma,
              plot=True, plot_png_title="tracks_2_ratesx10.png",
              plot_ylabel=r'$t \ \ (\boldsymbol{\lambda}\times 10)$')
plt.show()

# %%
#time lengths
delta_t = 0.3 
T = 5

#define parameters of the three-state model
V = np.array([2000, -1500, 0])
Lambda = np.array([1, 0.5, 0.3])
P = np.array([[0.0, 0.4, 0.6], [0.6, 0.0, 0.4], [0.6, 0.4, 0.0]])
sigma = 50
n = Lambda.shape[0]

#running the model with plot of the track
n_state_model(delta_t, T, V, Lambda, P, sigma,
              plot=True, plot_png_title="tracks_3.png"),
#              plot_ylabel=r'$t \ \ (\boldsymbol{\lambda}\times 1)$')
plt.show()

# %%
#time lengths
delta_t = 0.3 
T = 5

#define parameters of the three-state model ratesx10
V = np.array([2000, -1500, 0])
Lambda = np.array([1, 0.5, 0.3])*10
P = np.array([[0.0, 0.4, 0.6], [0.6, 0.0, 0.4], [0.6, 0.4, 0.0]])
sigma = 50
n = Lambda.shape[0]

#running the model with plot of the track
n_state_model(delta_t, T, V, Lambda, P, sigma,
              plot=True, plot_png_title="tracks_3_ratesx10.png")
#              plot_ylabel=r'$t \ \ (\boldsymbol{\lambda}\times 10)$')
plt.show()

# %%
#time lengths
delta_t = 0.3 
T = 5

#define parameters of the four-state model
V = np.array([2000, -1500, 0, 0])
Lambda = np.array([1, 0.5, 0.3, 2])
P = np.array([[0.0, 0.0, 0.5, 0.5], [0.0, 0.0, 0.5, 0.5],
              [0.0, 0.0, 0.0, 1.0], [0.6, 0.4, 0.0, 0.0]])
sigma = 50
n = Lambda.shape[0]

#running the model with plot of the track
n_state_model(delta_t, T, V, Lambda, P, sigma,
              plot=True, plot_png_title="tracks_4.png")
#              plot_ylabel=r'$t \ \ (\boldsymbol{\lambda}\times 1)$')
plt.show()

# %%
#time lengths
delta_t = 0.3 
T = 5

#define parameters of the four-state model ratesx10
V = np.array([2000, -1500, 0, 0])
Lambda = np.array([1, 0.5, 0.3, 2])*10
P = np.array([[0.0, 0.0, 0.5, 0.5], [0.0, 0.0, 0.5, 0.5],
              [0.0, 0.0, 0.0, 1.0], [0.6, 0.4, 0.0, 0.0]])
sigma = 50
n = Lambda.shape[0]

#running the model with plot of the track
n_state_model(delta_t, T, V, Lambda, P, sigma,
              plot=True, plot_png_title="tracks_4_ratesx10.png")
#              plot_ylabel=r'$t \ \ (\boldsymbol{\lambda}\times 10)$')
plt.show()

# %%
#time lengths
delta_t = 0.3 
T = 5

#define parameters of the six-state model
V = np.array([2000, -1500, 0, 0, 0, 0])
Lambda = np.array([1, 0.5, 0.3, 2, 2.2, 1.8])
P = np.array([[0.0, 0.0, 0.0, 0.2, 0.8, 0.0],
              [0.0, 0.0, 0.0, 0.2, 0.0, 0.8],
              [0.0, 0.0, 0.0, 0.0, 0.6, 0.4],
              [0.6, 0.4, 0.0, 0.0, 0.0, 0.0],
              [0.8, 0.0, 0.2, 0.0, 0.0, 0.0],
              [0.0, 0.8, 0.2, 0.0, 0.0, 0.0]])
sigma = 50
n = Lambda.shape[0]

#running the model with plot of the track
n_state_model(delta_t, T, V, Lambda, P, sigma,
              plot=True, plot_png_title="tracks_6.png")
#              plot_ylabel=r'$t \ \ (\boldsymbol{\lambda}\times 1)$')
plt.show()

# %%
#time lengths
delta_t = 0.3 
T = 5

#define parameters of the six-state model ratesx10
V = np.array([2000, -1500, 0, 0, 0, 0])
Lambda = np.array([1, 0.5, 0.3, 2, 2.2, 1.8])*10
P = np.array([[0.0, 0.0, 0.0, 0.2, 0.8, 0.0],
              [0.0, 0.0, 0.0, 0.2, 0.0, 0.8],
              [0.0, 0.0, 0.0, 0.0, 0.6, 0.4],
              [0.6, 0.4, 0.0, 0.0, 0.0, 0.0],
              [0.8, 0.0, 0.2, 0.0, 0.0, 0.0],
              [0.0, 0.8, 0.2, 0.0, 0.0, 0.0]])
sigma = 50
n = Lambda.shape[0]

#running the model with plot of the track
n_state_model(delta_t, T, V, Lambda, P, sigma,
              plot=True, plot_png_title="tracks_6_ratesx10.png")
#              plot_ylabel=r'$t \ \ (\boldsymbol{\lambda}\times 10)$')
plt.show()
